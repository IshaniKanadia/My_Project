# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\ishan\onedrive\documents\python scripts\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ishan\onedrive\documents\python scripts\lib\site-packages (from opencv-python) (1.24.3)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import cv2
import numpy as np

# %matplotlib inline

# Read in the image
image = mpimg.imread("C:\\Users\\ishan\\OneDrive\Desktop\\chandrayan.webp")
plt.figure(figsize=(10,10))
plt.imshow(image)

# %%
# Convert to grayscale for filtering
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
plt.figure(figsize=(10,10))
plt.imshow(gray, cmap='gray')

# %%
# Create a custom kernel

# 3x3 array for edge detection
sobel_y = np.array([[ -1, -2, -1], 
                   [ 0, 0, 0], 
                   [ 1, 2, 1]])

## TODO: Create and apply a Sobel x operator

# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
filtered_image = cv2.filter2D(gray, -1, sobel_y)
plt.figure(figsize=(10,10))
plt.imshow(filtered_image, cmap='gray')

# %%
# Create a custom kernel

# 3x3 array for edge detection
sobel_x = np.array([[ -1, 0, 1], 
                   [ -2, 0, 2], 
                   [ -1, 0, 1]])

## TODO: Create and apply a Sobel x operator


# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
filtered_image = cv2.filter2D(gray, -1, sobel_x)
plt.figure(figsize=(10,10))
plt.imshow(filtered_image, cmap='gray')
